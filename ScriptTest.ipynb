# %%
from ImageProcessScript import processImage
import matplotlib.pyplot as plt

# %%
for i in range(10):
    a,b,c=processImage(file_path="testingImage.jpg",minArea=(i/5)*0.00025)
    print(b)
# Out:
# 108
# 103
# 73
# 57
# 55
# 54
# 53
# 53
# 52
# 50
